# %%
import numpy as np
import pandas as pd

# %%
data_dir="mushrooms.csv"
df=pd.read_csv(data_dir)

# %%
df.head(10)
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
# 2    e         b           s         w       t    l               f
# 3    p         x           y         w       t    p               f
# 4    e         x           s         g       f    n               f
# 5    e         x           y         y       t    a               f
# 6    e         b           s         w       t    a               f
# 7    e         b           y         w       t    l               f
# 8    p         x           y         w       t    p               f
# 9    e         b           s         y       t    a               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
# 5            c         b          n  ...                        s
# 6            c         b          g  ...                        s
# 7            c         b          n  ...                        s
# 8            c         n          p  ...                        s
# 9            c         b          g  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
# 5                      w                      w         p          w
# 6                      w                      w         p          w
# 7                      w                      w         p          w
# 8                      w                      w         p          w
# 9                      w                      w         p          w
#
#   ring_number ring_type spore_print_color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
# 5           o         p                 k          n       g
# 6           o         p                 k          n       m
# 7           o         p                 n          s       m
# 8           o         p                 k          v       g
# 9           o         p                 k          s       m
#
# [10 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['type', 'cap_shape', 'cap_surface', 'cap_color', 'bruises', 'odor',
#        'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat'],
#       dtype='object')

# %%
df.shape
# Out:
# (8124, 23)

# %% [markdown]
# # Label encoding
# ## encodes categorical data to numerical data

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
mushroom=df.apply(le.fit_transform)

# %%
mushroom.head()
# Out:
#    type  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0     1          5            2          4        1     6                1
# 1     0          5            2          9        1     0                1
# 2     0          0            2          8        1     3                1
# 3     1          5            3          8        1     6                1
# 4     0          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color  ...  stalk_surface_below_ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring_number  ring_type  spore_print_color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
#df[['cap_surface','cap_color']].apply()

# %%
y=mushroom['type']
y[:5]
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: type, dtype: int32

# %%
x=mushroom.drop(columns=['type'])

# %%
x.head()
# Out:
#    cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk_surface_below_ring  stalk_color_above_ring  stalk_color_below_ring  \
# 0                         2                       7                       7
# 1                         2                       7                       7
# 2                         2                       7                       7
# 3                         2                       7                       7
# 4                         2                       7                       7
#
#    veil_type  veil_color  ring_number  ring_type  spore_print_color  \
# 0          0           2            1          4                  2
# 1          0           2            1          4                  3
# 2          0           2            1          4                  3
# 3          0           2            1          4                  2
# 4          0           2            1          0                  3
#
#    population  habitat
# 0           3        5
# 1           2        1
# 2           2        3
# 3           3        5
# 4           0        1
#
# [5 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((6499, 22), (6499,))

# %%
x_test.shape,y_test.shape
# Out:
# ((1625, 22), (1625,))

# %%
y_train.value_counts()/6499
# Out:
# 0    0.517772
# 1    0.482228
# Name: type, dtype: float64

# %%
x_test.loc[100]
# Out:
# cap_shape                   5
# cap_surface                 0
# cap_color                   4
# bruises                     0
# odor                        5
# gill_attachment             1
# gill_spacing                1
# gill_size                   0
# gill_color                  7
# stalk_shape                 1
# stalk_root                  3
# stalk_surface_above_ring    0
# stalk_surface_below_ring    2
# stalk_color_above_ring      7
# stalk_color_below_ring      7
# veil_type                   0
# veil_color                  2
# ring_number                 1
# ring_type                   0
# spore_print_color           2
# population                  3
# habitat                     1
# Name: 100, dtype: int32

# %%
poison_mushrooms=x_train[y_train==1]
poison_mushrooms
# Out:
#       cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 7873          3            2          2        0     7                1
# 6515          5            2          4        0     2                1
# 6141          2            3          2        0     8                1
# 5194          5            3          4        0     2                1
# 4525          2            3          3        0     2                1
# ...         ...          ...        ...      ...   ...              ...
# 5334          2            2          3        1     2                1
# 6265          2            2          2        0     7                1
# 5191          2            2          3        1     2                1
# 5226          5            3          4        0     2                1
# 7603          3            2          2        0     2                1
#
#       gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# 7873             0          1           0            1  ...
# 6515             0          1           0            1  ...
# 6141             0          1           0            1  ...
# 5194             0          1           0            1  ...
# 4525             0          0           7            0  ...
# ...            ...        ...         ...          ...  ...
# 5334             0          0           3            1  ...
# 6265             0          1           0            1  ...
# 5191             0          0           3            1  ...
# 5226             0          1           0            1  ...
# 7603             0          1           0            1  ...
#
#       stalk_surface_below_ring  stalk_color_above_ring  \
# 7873                         1                       6
# 6515                         2                       7
# 6141                         2                       6
# 5194                         1                       7
# 4525                         1                       6
# ...                        ...                     ...
# 5334                         0                       7
# 6265                         1                       6
# 5191                         2                       7
# 5226                         2                       6
# 7603                         2                       6
#
#       stalk_color_below_ring  veil_type  veil_color  ring_number  ring_type  \
# 7873                       7          0           2            1          0
# 6515                       7          0           2            1          0
# 6141                       7          0           2            1          0
# 5194                       6          0           2            1          0
# 4525                       4          0           2            1          2
# ...                      ...        ...         ...          ...        ...
# 5334                       7          0           2            1          4
# 6265                       6          0           2            1          0
# 5191                       7          0           2            1          4
# 5226                       7          0           2            1          0
# 7603                       6          0           2            1          0
#
#       spore_print_color  population  habitat
# 7873                  7           4        0
# 6515                  7           4        4
# 6141                  7           4        2
# 5194                  7           4        2
# 4525                  1           5        0
# ...                 ...         ...      ...
# 5334                  1           4        5
# 6265                  7           4        2
# 5191                  1           4        5
# 5226                  7           4        4
# 7603                  7           4        4
#
# [3134 rows x 22 columns]

# %%
(poison_mushrooms['cap_shape']==5).sum()
# Out:
# 1371

# %%
(poison_mushrooms['cap_shape']==5).sum()/3134
# Out:
# 0.4374601148691768

# %%
(poison_mushrooms['cap_surface']==0).sum()
# Out:
# 602

# %%
(poison_mushrooms['cap_surface']==0).sum()/3134
# Out:
# 0.19208679004467136

# %%
non_poison_mushrooms=x_train[y_train==0]
non_poison_mushrooms
# Out:
#       cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 2764          2            0          4        1     5                1
# 438           0            3          9        1     3                1
# 2629          5            0          4        1     5                1
# 5976          3            2          2        1     5                1
# 1721          2            2          8        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 3092          2            3          2        1     5                1
# 3772          2            3          4        1     5                1
# 5390          3            3          2        1     5                1
# 860           2            3          4        1     3                1
# 7270          3            0          3        0     5                1
#
#       gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# 2764             0          0           9            1  ...
# 438              0          0           4            0  ...
# 2629             0          0          10            1  ...
# 5976             0          0           1            0  ...
# 1721             1          0           7            1  ...
# ...            ...        ...         ...          ...  ...
# 3092             0          0           9            1  ...
# 3772             0          0           7            1  ...
# 5390             0          0          10            0  ...
# 860              0          0          10            0  ...
# 7270             1          0           2            0  ...
#
#       stalk_surface_below_ring  stalk_color_above_ring  \
# 2764                         2                       3
# 438                          2                       7
# 2629                         2                       3
# 5976                         2                       7
# 1721                         2                       7
# ...                        ...                     ...
# 3092                         2                       3
# 3772                         2                       3
# 5390                         2                       7
# 860                          3                       7
# 7270                         1                       7
#
#       stalk_color_below_ring  veil_type  veil_color  ring_number  ring_type  \
# 2764                       6          0           2            1          4
# 438                        7          0           2            1          4
# 2629                       3          0           2            1          4
# 5976                       7          0           2            2          0
# 1721                       7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 3092                       3          0           2            1          4
# 3772                       6          0           2            1          4
# 5390                       2          0           2            2          0
# 860                        7          0           2            1          4
# 7270                       7          0           2            2          4
#
#       spore_print_color  population  habitat
# 2764                  3           4        0
# 438                   3           2        3
# 2629                  3           5        0
# 5976                  7           1        6
# 1721                  2           0        1
# ...                 ...         ...      ...
# 3092                  3           5        0
# 3772                  3           4        0
# 5390                  7           1        6
# 860                   3           5        4
# 7270                  7           2        1
#
# [3365 rows x 22 columns]

# %%
(non_poison_mushrooms['cap_shape']==5).sum()
# Out:
# 1585

# %%
(non_poison_mushrooms['cap_shape']==5).sum()/3365
# Out:
# 0.4710252600297177

# %%
(non_poison_mushrooms['cap_surface']==0).sum()/3365
# Out:
# 0.3696879643387816

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model=MultinomialNB()

# %%
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
model.predict_proba(x_test).round(2)
# Out:
# array([[0.93, 0.07],
#        [0.  , 1.  ],
#        [0.  , 1.  ],
#        ...,
#        [0.  , 1.  ],
#        [0.  , 1.  ],
#        [0.63, 0.37]])

# %%
model.predict(x_test)
# Out:
# array([0, 1, 1, ..., 1, 1, 0])

# %%
model.score(x_test,y_test)
# Out:
# 0.8073846153846154

# %%
model.score(x_train,y_train)
# Out:
# 0.8052008001230958

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\arora\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.947076923076923

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model.score(x_test,y_test)
# Out:
# 0.9981538461538462
